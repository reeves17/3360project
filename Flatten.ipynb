# %% [markdown]
# # Josh Bielenberg Exploring Data

# %% [markdown]
# Import relevant packages

# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import ast

# %% [markdown]
# # Create a new dataframe that flattens out the ratings into a column for each category with each video's count for each rating
#
# (This code took about 30 seconds on my laptop)

# %%
tedTalks = pd.read_csv("ted_main.csv")
transcripts = pd.read_csv("transcripts.csv")

columns = ['Funny','Beautiful','Ingenious','Courageous','Longwinded','Confusing','Informative','Fascinating','Unconvincing','Persuasive','Jaw-dropping','OK','Obnoxious','Inspiring']
flatten = pd.DataFrame(columns=columns)

for index, row in tedTalks.iterrows():
    t = ast.literal_eval(row['ratings'])
    df = pd.DataFrame(json_normalize(t))
    flatten = flatten.append(df.set_index('name').T.iloc[0])

flatten = flatten.reset_index()
flatten = flatten.drop(['index'], axis=1)  
flatten.head(3)
# Out:
#    Funny Beautiful Ingenious Courageous Longwinded Confusing Informative  \
# 0  19645      4573      6073       3253        387       242        7346
# 1    544        58        56        139        113        62         443
# 2    964        60       183         45         78        27         395
#
#   Fascinating Unconvincing Persuasive Jaw-dropping    OK Obnoxious Inspiring
# 0       10581          300      10704         4439  1174       209     24924
# 1         132          258        268          116   203       131       413
# 2         166          104        230           54   146       142       230

# %%
flatten.Funny = flatten.Funny.astype('int64')
flatten.Beautiful = flatten.Beautiful.astype('int64')
flatten.Ingenious = flatten.Ingenious.astype('int64')
flatten.Courageous = flatten.Courageous.astype('int64')
flatten.Longwinded = flatten.Longwinded.astype('int64')
flatten.Confusing = flatten.Confusing.astype('int64')
flatten.Informative = flatten.Informative.astype('int64')
flatten.Fascinating = flatten.Fascinating.astype('int64')
flatten.Unconvincing = flatten.Unconvincing.astype('int64')
flatten.Persuasive = flatten.Persuasive.astype('int64')
flatten['Jaw-dropping'] = flatten['Jaw-dropping'].astype('int64')
flatten.OK = flatten.OK.astype('int64')
flatten.Obnoxious = flatten.Obnoxious.astype('int64')
flatten.Inspiring = flatten.Inspiring.astype('int64')
tedTalks = tedTalks.join(flatten)
tedTalks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550 entries, 0 to 2549
# Data columns (total 31 columns):
# comments              2550 non-null int64
# description           2550 non-null object
# duration              2550 non-null int64
# event                 2550 non-null object
# film_date             2550 non-null int64
# languages             2550 non-null int64
# main_speaker          2550 non-null object
# name                  2550 non-null object
# num_speaker           2550 non-null int64
# published_date        2550 non-null int64
# ratings               2550 non-null object
# related_talks         2550 non-null object
# speaker_occupation    2544 non-null object
# tags                  2550 non-null object
# title                 2550 non-null object
# url                   2550 non-null object
# views                 2550 non-null int64
# Funny                 2550 non-null int64
# Beautiful             2550 non-null int64
# Ingenious             2550 non-null int64
# Courageous            2550 non-null int64
# Longwinded            2550 non-null int64
# Confusing             2550 non-null int64
# Informative           2550 non-null int64
# Fascinating           2550 non-null int64
# Unconvincing          2550 non-null int64
# Persuasive            2550 non-null int64
# Jaw-dropping          2550 non-null int64
# OK                    2550 non-null int64
# Obnoxious             2550 non-null int64
# Inspiring             2550 non-null int64
# dtypes: int64(21), object(10)
# memory usage: 617.6+ KB

# %%
tedTalks.head(3)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#      ...     Longwinded Confusing Informative Fascinating Unconvincing  \
# 0    ...            387       242        7346       10581          300
# 1    ...            113        62         443         132          258
# 2    ...             78        27         395         166          104
#
#   Persuasive  Jaw-dropping    OK  Obnoxious  Inspiring
# 0      10704          4439  1174        209      24924
# 1        268           116   203        131        413
# 2        230            54   146        142        230
#
# [3 rows x 31 columns]

# %%
tedTalks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550 entries, 0 to 2549
# Data columns (total 31 columns):
# comments              2550 non-null int64
# description           2550 non-null object
# duration              2550 non-null int64
# event                 2550 non-null object
# film_date             2550 non-null int64
# languages             2550 non-null int64
# main_speaker          2550 non-null object
# name                  2550 non-null object
# num_speaker           2550 non-null int64
# published_date        2550 non-null int64
# ratings               2550 non-null object
# related_talks         2550 non-null object
# speaker_occupation    2544 non-null object
# tags                  2550 non-null object
# title                 2550 non-null object
# url                   2550 non-null object
# views                 2550 non-null int64
# Funny                 2550 non-null int64
# Beautiful             2550 non-null int64
# Ingenious             2550 non-null int64
# Courageous            2550 non-null int64
# Longwinded            2550 non-null int64
# Confusing             2550 non-null int64
# Informative           2550 non-null int64
# Fascinating           2550 non-null int64
# Unconvincing          2550 non-null int64
# Persuasive            2550 non-null int64
# Jaw-dropping          2550 non-null int64
# OK                    2550 non-null int64
# Obnoxious             2550 non-null int64
# Inspiring             2550 non-null int64
# dtypes: int64(21), object(10)
# memory usage: 617.6+ KB

# %% [markdown]
# # Go through the related talks column to find the id for each video
#
# (This code took about two minutes on my laptop)

# %%
relatedVideos = pd.DataFrame()

for index, row in tedTalks.iterrows():
    array = ast.literal_eval(row['related_talks'])
    for json in array:
        relatedVideos = relatedVideos.append(json_normalize(json))

relatedVideos.head(3)
# Out:
#    duration                                               hero    id  \
# 0      1008  https://pe.tedcdn.com/images/ted/172559_800x60...   865
# 0      1151  https://pe.tedcdn.com/images/ted/de98b161ad143...  1738
# 0      1027  https://pe.tedcdn.com/images/ted/3821f3728e0b7...  2276
#
#                                                 slug              speaker  \
# 0           sir_ken_robinson_bring_on_the_revolution         Ken Robinson
# 0  ken_robinson_how_to_escape_education_s_death_v...         Ken Robinson
# 0  linda_cliatt_wayman_how_to_fix_a_broken_school...  Linda Cliatt-Wayman
#
#                                                title  viewed_count
# 0                  Bring on the learning revolution!       7266103
# 0             How to escape education's death valley       6657572
# 0  How to fix a broken school? Lead fearlessly, l...       1617101

# %% [markdown]
# Merge the ids onto the tedTalks dataframe

# %%
idAdded = relatedVideos[['id','title']].drop_duplicates()
tedTalks = pd.merge(tedTalks,idAdded,on='title')
tedTalks
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# 11          55  Jehane Noujaim unveils her 2006 TED Prize wish...      1538
# 12          71  Accepting the 2006 TED Prize, Dr. Larry Brilli...      1550
# 13         242  Jeff Han shows off a cheap, scalable multi-tou...       527
# 14          99  Nicholas Negroponte, founder of the MIT Media ...      1057
# 15         325  Violinist Sirena Huang gives a technically bri...      1481
# 16         305  Pianist and composer Jennifer Lin gives a magi...      1445
# 17          88  Fumes from indoor cooking fires kill more than...       906
# 18         163  Designer Ross Lovegrove expounds his philosoph...      1170
# 19          84  Jimmy Wales recalls how he assembled "a ragtag...      1201
# 20         185  Performer and web toymaker Ze Frank delivers a...      1136
# 21          50  The founding mother of the blog revolution, Mo...      1006
# 22         556  Anthropologist Helen Fisher takes on a tricky ...      1407
# 23         117  Eve Ensler, creator of "The Vagina Monologues,...      1225
# 24         184  Legendary scientist David Deutsch puts theoret...      1140
# 25         507  Biologist Richard Dawkins makes a case for "th...      1316
# 26          95  "Freakonomics" author Steven Levitt presents n...      1275
# 27         355  "Tipping Point" author Malcolm Gladwell gets i...      1050
# 28         970  Dan Gilbert, author of "Stumbling on Happiness...      1276
# 29         991  Psychologist Barry Schwartz takes aim at a cen...      1177
# ...        ...                                                ...       ...
# 2417        20  Should your driverless car kill you if it mean...       815
# 2418        14  With his signature charm and searching insight...      1215
# 2419        81  Meet the "ems" -- machines that emulate human ...       736
# 2420        13  Your cells are coated with sugars that store i...       685
# 2421        12  Every artist has a name, and every artist has ...       530
# 2422        20  Another economic reality is possible -- one th...       747
# 2423        18  Could it be wrong to help children in need by ...       791
# 2424        39  Meet Todai Robot, an AI project that performed...       817
# 2425        17  What's stopping the American government from r...       865
# 2426         3  Digital archaeologist Chance Coughenour is usi...       717
# 2427        45  We all have origin stories and identity myths,...      1156
# 2428        12  Daan Roosegaarde uses technology and creative ...       738
# 2429        18  Terrorists and extremists aren't all naturally...       698
# 2430        25  What if you knew what your coworkers really th...       993
# 2431         9  In a mind-bending talk that blurs the line bet...       663
# 2432         2  What the astronauts felt when they saw Earth f...       725
# 2433         8  Underneath every shiny new megacity, there's o...       723
# 2434        21  Can you still be friends with someone who does...       865
# 2435        39  Our culture is obsessed with happiness, but wh...       738
# 2436         7  Each year, one in seven large corporations com...       808
# 2437        10  Forget quinoa. Meet fonio, an ancient "miracle...       934
# 2438        33  We've heard a lot of rhetoric lately suggestin...       722
# 2439        12  Physics doesn't just happen in a fancy lab -- ...       957
# 2440         3  In the century-old statues that occupy Cape To...       795
# 2441         7  What if you could know exactly how food or med...       894
# 2442        10  How can Africa, the home to some of the larges...       810
# 2443        17  Between 2008 and 2016, the United States depor...       476
# 2444         6  How can you study Mars without a spaceship? He...       290
# 2445        10  Science fiction visions of the future show us ...       651
# 2446        32  In an unmissable talk about race and politics ...      1100
#
#                event   film_date  languages  \
# 0            TED2006  1140825600         60
# 1            TED2006  1140825600         43
# 2            TED2006  1140739200         26
# 3            TED2006  1140912000         35
# 4            TED2006  1140566400         48
# 5            TED2006  1138838400         36
# 6            TED2006  1140739200         31
# 7            TED2006  1140652800         19
# 8            TED2006  1138838400         32
# 9            TED2006  1140825600         31
# 10           TED2006  1140912000         27
# 11           TED2006  1140912000         20
# 12           TED2006  1140652800         24
# 13           TED2006  1139184000         27
# 14           TED2006  1140652800         25
# 15           TED2006  1140652800         31
# 16           TED2004  1077753600         32
# 17           TED2006  1140739200         27
# 18           TED2005  1109289600         22
# 19    TEDGlobal 2005  1121299200         32
# 20           TED2004  1077580800         26
# 21           TED2006  1140652800         20
# 22           TED2006  1140739200         33
# 23           TED2004  1075852800         23
# 24    TEDGlobal 2005  1121299200         29
# 25    TEDGlobal 2005  1120694400         36
# 26           TED2004  1077840000         25
# 27           TED2004  1077753600         37
# 28           TED2004  1075680000         43
# 29    TEDGlobal 2005  1121385600         45
# ...              ...         ...        ...
# 2417   TEDxCambridge  1475107200          8
# 2418         TED2017  1492992000          4
# 2419         TED2017  1492992000          2
# 2420    TEDxStanford  1461456000          7
# 2421         TED2017  1492992000          5
# 2422    TEDxCrenshaw  1475884800          3
# 2423      TEDxSydney  1464048000          5
# 2424         TED2017  1492992000          6
# 2425    TEDxStanford  1492905600          3
# 2426     TEDxHamburg  1465344000          5
# 2427      TEDxExeter  1429833600          1
# 2428         TED2017  1492992000          3
# 2429       TEDxGhent  1466208000          1
# 2430         TED2017  1492992000          2
# 2431         TED2017  1492992000          2
# 2432       TEDxSkoll  1491523200          1
# 2433  TEDGlobal 2017  1503792000          4
# 2434    TEDxMileHigh  1499472000          5
# 2435         TED2017  1492992000          2
# 2436      TEDxZurich  1478822400          1
# 2437         TED2017  1503792000          2
# 2438         TED@UPS  1500508800          4
# 2439  TEDxManchester  1487462400          2
# 2440  TEDGlobal 2017  1503792000          1
# 2441         TED2017  1492992000          1
# 2442  TEDGlobal 2017  1503792000          1
# 2443         TED2017  1496707200          4
# 2444         TED2017  1492992000          3
# 2445         TED2017  1492992000          1
# 2446    TEDxMileHigh  1499472000          1
#
#                                 main_speaker  \
# 0                               Ken Robinson
# 1                                    Al Gore
# 2                                David Pogue
# 3                              Majora Carter
# 4                               Hans Rosling
# 5                               Tony Robbins
# 6                              Julia Sweeney
# 7                        Joshua Prince-Ramus
# 8                                Dan Dennett
# 9                                Rick Warren
# 10                          Cameron Sinclair
# 11                            Jehane Noujaim
# 12                           Larry Brilliant
# 13                                  Jeff Han
# 14                       Nicholas Negroponte
# 15                              Sirena Huang
# 16                              Jennifer Lin
# 17                                 Amy Smith
# 18                            Ross Lovegrove
# 19                               Jimmy Wales
# 20                                  Ze Frank
# 21                                Mena Trott
# 22                              Helen Fisher
# 23                                Eve Ensler
# 24                             David Deutsch
# 25                           Richard Dawkins
# 26                             Steven Levitt
# 27                          Malcolm Gladwell
# 28                               Dan Gilbert
# 29                            Barry Schwartz
# ...                                      ...
# 2417                             Iyad Rahwan
# 2418                             David Whyte
# 2419                            Robin Hanson
# 2420                        Carolyn Bertozzi
# 2421                          Laolu Senbanjo
# 2422                               Niki Okuk
# 2423                            Tara Winkler
# 2424                             Noriko Arai
# 2425                        Jennifer Granick
# 2426                       Chance Coughenour
# 2427                            Chetan Bhatt
# 2428                        Daan Roosegaarde
# 2429                      Erin Marie Saltman
# 2430                               Ray Dalio
# 2431                         Tomás Saraceno
# 2432                          Benjamin Grant
# 2433                     OluTimehin Adegbeye
# 2434  Caitlin Quattromani and Lauran Arledge
# 2435                    Emily Esfahani Smith
# 2436                        Alexander Wagner
# 2437                            Pierre Thiam
# 2438                            Augie Picado
# 2439                           Helen Czerski
# 2440                      Sethembile Msezane
# 2441                                Jun Wang
# 2442                     Olúfẹ́mi Táíwò
# 2443                        Duarte Geraldino
# 2444                     Armando Azua-Bustos
# 2445                          Radhika Nagpal
# 2446                        Theo E.J. Wilson
#
#                                                    name  num_speaker  \
# 0             Ken Robinson: Do schools kill creativity?            1
# 1                  Al Gore: Averting the climate crisis            1
# 2                         David Pogue: Simplicity sells            1
# 3                    Majora Carter: Greening the ghetto            1
# 4         Hans Rosling: The best stats you've ever seen            1
# 5                    Tony Robbins: Why we do what we do            1
# 6                      Julia Sweeney: Letting go of God            1
# 7     Joshua Prince-Ramus: Behind the design of Seat...            1
# 8     Dan Dennett: Let's teach religion -- all relig...            1
# 9                        Rick Warren: A life of purpose            1
# 10    Cameron Sinclair: My wish: A call for open-sou...            1
# 11        Jehane Noujaim: My wish: A global day of film            1
# 12     Larry Brilliant: My wish: Help me stop pandemics            1
# 13    Jeff Han: The radical promise of the multi-tou...            1
# 14            Nicholas Negroponte: One Laptop per Child            1
# 15        Sirena Huang: An 11-year-old's magical violin            1
# 16          Jennifer Lin: Improvising on piano, aged 14            1
# 17             Amy Smith: Simple designs to save a life            1
# 18    Ross Lovegrove: Organic design, inspired by na...            1
# 19                  Jimmy Wales: The birth of Wikipedia            1
# 20                            Ze Frank: Nerdcore comedy            1
# 21    Mena Trott: Meet the founder of the blog revol...            1
# 22              Helen Fisher: Why we love, why we cheat            1
# 23               Eve Ensler: Happiness in body and soul            1
# 24    David Deutsch: Chemical scum that dream of dis...            1
# 25    Richard Dawkins: Why the universe seems so str...            1
# 26     Steven Levitt: The freakonomics of crack dealing            1
# 27    Malcolm Gladwell: Choice, happiness and spaghe...            1
# 28     Dan Gilbert: The surprising science of happiness            1
# 29                Barry Schwartz: The paradox of choice            1
# ...                                                 ...          ...
# 2417  Iyad Rahwan: What moral decisions should drive...            1
# 2418  David Whyte: A lyrical bridge between past, pr...            1
# 2419  Robin Hanson: What would happen if we upload o...            1
# 2420  Carolyn Bertozzi: What the sugar coating on yo...            1
# 2421        Laolu Senbanjo: "The Sacred Art of the Ori"            1
# 2422  Niki Okuk: When workers own companies, the eco...            1
# 2423  Tara Winkler: Why we need to end the era of or...            1
# 2424  Noriko Arai: Can a robot pass a university ent...            1
# 2425  Jennifer Granick: How the US government spies ...            1
# 2426  Chance Coughenour: How your pictures can help ...            1
# 2427  Chetan Bhatt: Dare to refuse the origin myths ...            1
# 2428  Daan Roosegaarde: A smog vacuum cleaner and ot...            1
# 2429  Erin Marie Saltman: How young people join viol...            1
# 2430  Ray Dalio: How to build a company where the be...            1
# 2431  Tomás Saraceno: Would you live in a floating ...            1
# 2432  Benjamin Grant: What it feels like to see Eart...            1
# 2433        OluTimehin Adegbeye: Who belongs in a city?            1
# 2434  Caitlin Quattromani and Lauran Arledge: How ou...            2
# 2435  Emily Esfahani Smith: There's more to life tha...            1
# 2436  Alexander Wagner: What really motivates people...            1
# 2437  Pierre Thiam: A forgotten ancient grain that c...            1
# 2438  Augie Picado: The real reason manufacturing jo...            1
# 2439  Helen Czerski: The fascinating physics of ever...            1
# 2440  Sethembile Msezane: Living sculptures that sta...            1
# 2441  Jun Wang: How digital DNA could help you make ...            1
# 2442  Olúfẹ́mi Táíwò: Why Africa must become a ...            1
# 2443  Duarte Geraldino: What we're missing in the de...            1
# 2444  Armando Azua-Bustos: The most Martian place on...            1
# 2445  Radhika Nagpal: What intelligent machines can ...            1
# 2446  Theo E.J. Wilson: A black man goes undercover ...            1
#
#       published_date  ...  Confusing Informative Fascinating Unconvincing  \
# 0         1151367060  ...        242        7346       10581          300
# 1         1151367060  ...         62         443         132          258
# 2         1151367060  ...         27         395         166          104
# 3         1151367060  ...         32         380         132           36
# 4         1151440680  ...         72        5433        4606           67
# 5         1151440680  ...        301        1038        1350          377
# 6         1152490260  ...         72         226         316          225
# 7         1152490260  ...         25         121         153           26
# 8         1153181460  ...         70         623         313          283
# 9         1153181460  ...        111         304         459          838
# 10        1153786260  ...         14         187         148           21
# 11        1153786260  ...          7          33          41           14
# 12        1153786260  ...          2         188          83            5
# 13        1154391060  ...         19         461         919           32
# 14        1154391060  ...          6         104          67           31
# 15        1154995860  ...         10          22         635           15
# 16        1154995860  ...         22          32         454           53
# 17        1155600660  ...          7         279         159           13
# 18        1155600660  ...         80          71         220          113
# 19        1156119060  ...         13         478         181           14
# 20        1156464660  ...        203          61         177          137
# 21        1156464660  ...         40          82          34           67
# 22        1157501460  ...        115        2591        2106          249
# 23        1157501460  ...         13         154         144           27
# 24        1158019860  ...         42         446         515           49
# 25        1158019860  ...         42         653        1281           41
# 26        1158624660  ...          7         532         404           19
# 27        1158624660  ...         80        2004        2082          115
# 28        1159229460  ...        241        3899        4303          174
# 29        1159229460  ...         54        2532        2491          324
# ...              ...  ...        ...         ...         ...          ...
# 2417      1503432025  ...          2          64          35            2
# 2418      1503500147  ...          2           5          49            1
# 2419      1503586288  ...         11          53          64           26
# 2420      1503604806  ...          0         146          64            1
# 2421      1503673077  ...          4          24          42            1
# 2422      1503932075  ...         10          47          31           33
# 2423      1504036846  ...          1          91          30            6
# 2424      1504105251  ...          1         129         114            8
# 2425      1504190944  ...          5         112          10           18
# 2426      1504209631  ...          0           5          16            0
# 2427      1504276143  ...         11          97          56           28
# 2428      1504623555  ...          2          40          79            6
# 2429      1504641624  ...          0          64          16            5
# 2430      1504709317  ...          3         214         170           10
# 2431      1504796048  ...          6          16          24            4
# 2432      1504814438  ...          0          50          36            3
# 2433      1504882266  ...          1          71          34            2
# 2434      1505142060  ...          1          15          15           12
# 2435      1505227376  ...          8         294         170           27
# 2436      1505246451  ...          0          51          54            4
# 2437      1505313942  ...          0          78          28            3
# 2438      1505400604  ...          4         157          35           38
# 2439      1505419202  ...         12          91          52           10
# 2440      1505488093  ...          1          15          14            5
# 2441      1505747687  ...          3          68          31            4
# 2442      1505833613  ...          0          37          15            1
# 2443      1505851216  ...          2          33           8           12
# 2444      1505919737  ...          0          38          32            1
# 2445      1506006095  ...          5          32          24            1
# 2446      1506024042  ...          1          75          39            6
#
#      Persuasive Jaw-dropping    OK  Obnoxious  Inspiring    id
# 0         10704         4439  1174        209      24924    66
# 1           268          116   203        131        413     1
# 2           230           54   146        142        230     7
# 3           460          230    85         35       1070    53
# 4          2542         3736   248         61       2893    92
# 5          2423          669   441        335       5211    96
# 6           311           61   308        290        438    86
# 7            37           57    63          5        175    49
# 8           764           60   154         83        441    94
# 9          1543          209   245        371       2556    71
# 10          160           66    39          7        608    54
# 11           42           20    26          1        201    55
# 12          111           70    11          5        240    58
# 13           77         4643   188         23        471    65
# 14           49           29    30         11        216    41
# 15           41         2280    95         39        879    45
# 16           22         1997    68         31        552    46
# 17          140           63    30          4        515     2
# 18           22           93    68        210        363    27
# 19           73           54    68         11        277    37
# 20           20           80   450        239        196    87
# 21           23            3    87         41         86    21
# 22         1513          207   394        111       1083    16
# 23           97           97    26         43        789    64
# 24         1234          139    73         21        397    47
# 25          367          324    93         39        674    98
# 26          109           61    44         17         43    29
# 27         1014          290   361         51       1276    20
# 28         2355         1047   439         67       3554    97
# 29         2478          521   421        115       2427    93
# ...         ...          ...   ...        ...        ...   ...
# 2417         14            3     1          2         15  2824
# 2418          8            8     7          6        152  2846
# 2419          1           27    29         11         14  2858
# 2420         18           13     2          1         31  2850
# 2421          4           10     7          1         69  2863
# 2422         31            4    10         14         99  2847
# 2423         37           31     7          2        119  2848
# 2424         51           19    10          3         49  2852
# 2425         36           17    10         11         18  2866
# 2426          5            4     0          0         12  2854
# 2427         81            2    13          4        149  2864
# 2428         24           20     7          0        148  2855
# 2429         18            1     5          0         22  2856
# 2430         96           13    26          7        218  2859
# 2431          7           13     8          1         42  2865
# 2432         18           17     3          3         46  2853
# 2433         63           16     3          1         72  2873
# 2434         40            0     5          7         72  2876
# 2435        124           29    61          8        677  2861
# 2436         25            1    11          3         50  2835
# 2437         36            3     0          0         73  2875
# 2438         62            7     9         18         18  2867
# 2439         26            3    14          3         60  2862
# 2440          2            3     1          5         35  2880
# 2441         12            5     3          4         41  2871
# 2442         30            0     6          1         31  2881
# 2443         24           14     0          1         27  2879
# 2444          7            8    13          0         20  2869
# 2445          3            1     4          0         30  2870
# 2446         65            7     5          7        147  2887
#
# [2447 rows x 32 columns]

# %% [markdown]
# # Extract an array of related video IDs from related videos column

# %%
tedTalks['relatedIds'] = np.empty((len(tedTalks), 0)).tolist()

for index, row in tedTalks.iterrows():
    array = ast.literal_eval(row['related_talks'])
    for x in array:
        tedTalks['relatedIds'][index].append(x['id'])

tedTalks.head(3)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
# 2              David Pogue: Simplicity sells            1      1151367060
#
#                   ...                 Informative Fascinating Unconvincing  \
# 0                 ...                        7346       10581          300
# 1                 ...                         443         132          258
# 2                 ...                         395         166          104
#
#   Persuasive Jaw-dropping    OK  Obnoxious  Inspiring  id  \
# 0      10704         4439  1174        209      24924  66
# 1        268          116   203        131        413   1
# 2        230           54   146        142        230   7
#
#                            relatedIds
# 0  [865, 1738, 2276, 892, 1232, 2616]
# 1  [243, 547, 2093, 2784, 2339, 2331]
# 2  [1725, 2274, 172, 2664, 436, 1546]
#
# [3 rows x 33 columns]

# %% [markdown]
# # Save the new dataframe into tedTalksFlattened.csv

# %%
tedTalks.to_csv("tedTalksFlattened.csv")
